# %%
import pandas as pd
input_path = "/home/toor/PycharmProjects/FinalV3/data/results.csv"
df = pd.read_csv(input_path, dtype={"gvkey": "string"}, parse_dates=["char_eom"])

# %%
# Out:
# (613158, 15)

# %%
df_unique = df.drop_duplicates(subset=["id", "char_eom"], keep="first")

# %%
df_unique.to_csv("resultss1.csv", index=False)
